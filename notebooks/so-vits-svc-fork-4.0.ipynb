# %% [markdown]
# ## Before training
#
# This program saves the last 3 generations of models to Google Drive. Since 1 generation of models is >1GB, you should have at least 3GB of free space in Google Drive. If you do not have such free space, it is recommended to create another Google Account.
#
# Training requires >10GB VRAM. (T4 should be enough) Inference does not require such a lot of VRAM.

# %% [markdown]
# ## Installation

# %%
#@title Check GPU
# !nvidia-smi
# Out:
# Sun May 11 01:56:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   36C    P8             11W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
#@title Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Install dependencies
#@markdown pip may fail to resolve dependencies and raise ERROR, but it can be ignored.
# !python -m pip install -U pip wheel
# %pip install -U ipython
#@markdown Branch (for development)
BRANCH = "none" #@param {"type": "string"}
if BRANCH == "none":
    # %pip install -U so-vits-svc-fork
else:
    # %pip install -U git+https://github.com/34j/so-vits-svc-fork.git@{BRANCH}
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (0.45.1)
# Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.6 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.1.1
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (7.34.0)
# Collecting ipython
#   Downloading ipython-9.2.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython) (4.4.2)
# Collecting ipython-pygments-lexers (from ipython)
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.16 (from ipython)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.11/dist-packages (from ipython) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from ipython) (2.19.1)
# Collecting stack_data (from ipython)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing_extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from ipython) (4.13.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython) (0.7.0)
# Collecting executing>=1.2.0 (from stack_data->ipython)
#   Downloading executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython)
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading ipython-9.2.0-py3-none-any.whl (604 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.3/604.3 kB 20.0 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.1 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Installing collected packages: pure-eval, traitlets, jedi, ipython-pygments-lexers, executing, asttokens, stack_data, ipython
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [ipython]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 9.2.0 which is incompatible.
# Successfully installed asttokens-3.0.0 executing-2.2.0 ipython-9.2.0 ipython-pygments-lexers-1.1.1 jedi-0.19.2 pure-eval-0.2.3 stack_data-0.6.3 traitlets-5.14.3
# Collecting so-vits-svc-fork
#   Downloading so_vits_svc_fork-4.2.26-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: SoundFile in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (0.13.1)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (8.1.8)
# Collecting cm-time>=0.1.2 (from so-vits-svc-fork)
#   Downloading cm_time-0.1.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting fastapi==0.111.1 (from so-vits-svc-fork)
#   Downloading fastapi-0.111.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (0.11.0)
# Collecting lightning<3.0.0,>=2.0.1 (from so-vits-svc-fork)
#   Downloading lightning-2.5.1.post0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (3.10.0)
# Collecting numpy<2.0.0,>=1.26.4 (from so-vits-svc-fork)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting onnx (from so-vits-svc-fork)
#   Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting onnxoptimizer (from so-vits-svc-fork)
#   Downloading onnxoptimizer-0.3.13-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting onnxsim (from so-vits-svc-fork)
#   Downloading onnxsim-0.4.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting pebble>=5.0 (from so-vits-svc-fork)
#   Downloading pebble-5.1.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting praat-parselmouth (from so-vits-svc-fork)
#   Downloading praat_parselmouth-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Collecting pysimplegui-4-foss<5.0.0.0,>=4.60.4.1 (from so-vits-svc-fork)
#   Downloading PySimpleGUI_4_foss-4.60.4.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyworld (from so-vits-svc-fork)
#   Downloading pyworld-0.3.5.tar.gz (261 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (13.9.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (1.15.2)
# Collecting setuptools<70.0.0,>=69.5.1 (from so-vits-svc-fork)
#   Downloading setuptools-69.5.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting sounddevice (from so-vits-svc-fork)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (2.18.0)
# Collecting tensorboardx (from so-vits-svc-fork)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: torch<3,>=2 in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (2.6.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (2.6.0+cu124)
# Collecting torchcrepe>=0.0.17 (from so-vits-svc-fork)
#   Downloading torchcrepe-0.0.23-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (4.67.1)
# Collecting tqdm-joblib<0.0.5,>=0.0.4 (from so-vits-svc-fork)
#   Downloading tqdm_joblib-0.0.4-py3-none-any.whl.metadata (269 bytes)
# Requirement already satisfied: transformers<5.0.0,>=4.28.1 in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (4.51.3)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi==0.111.1->so-vits-svc-fork)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from fastapi==0.111.1->so-vits-svc-fork) (2.11.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi==0.111.1->so-vits-svc-fork) (4.13.2)
# Collecting fastapi-cli>=0.0.2 (from fastapi==0.111.1->so-vits-svc-fork)
#   Downloading fastapi_cli-0.0.7-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from fastapi==0.111.1->so-vits-svc-fork) (0.28.1)
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.11/dist-packages (from fastapi==0.111.1->so-vits-svc-fork) (3.1.6)
# Collecting python-multipart>=0.0.7 (from fastapi==0.111.1->so-vits-svc-fork)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting email_validator>=2.0.0 (from fastapi==0.111.1->so-vits-svc-fork)
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting uvicorn>=0.12.0 (from uvicorn[standard]>=0.12.0->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (2025.3.2)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning<3.0.0,>=2.0.1->so-vits-svc-fork)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.11/dist-packages (from lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (24.2)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning<3.0.0,>=2.0.1->so-vits-svc-fork)
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting pytorch-lightning (from lightning<3.0.0,>=2.0.1->so-vits-svc-fork)
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (3.11.15)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.111.1->so-vits-svc-fork) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.111.1->so-vits-svc-fork) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.111.1->so-vits-svc-fork) (0.4.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from starlette<0.38.0,>=0.37.2->fastapi==0.111.1->so-vits-svc-fork) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi==0.111.1->so-vits-svc-fork) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi==0.111.1->so-vits-svc-fork) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (3.4.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2->so-vits-svc-fork) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.28.1->so-vits-svc-fork) (0.30.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.28.1->so-vits-svc-fork) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.28.1->so-vits-svc-fork) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.28.1->so-vits-svc-fork) (0.5.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (1.20.0)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.11/dist-packages (from fastapi-cli>=0.0.2->fastapi==0.111.1->so-vits-svc-fork) (0.15.3)
# Collecting rich-toolkit>=0.11.1 (from fastapi-cli>=0.0.2->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading rich_toolkit-0.14.5-py3-none-any.whl.metadata (999 bytes)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->fastapi==0.111.1->so-vits-svc-fork) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->fastapi==0.111.1->so-vits-svc-fork) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.23.0->fastapi==0.111.1->so-vits-svc-fork) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.11.2->fastapi==0.111.1->so-vits-svc-fork) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->so-vits-svc-fork) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->so-vits-svc-fork) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->so-vits-svc-fork) (0.1.2)
# Collecting resampy (from torchcrepe>=0.0.17->so-vits-svc-fork)
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (1.1.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa->so-vits-svc-fork) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->so-vits-svc-fork) (4.3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->so-vits-svc-fork) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->so-vits-svc-fork) (2.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa->so-vits-svc-fork) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from SoundFile->so-vits-svc-fork) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->SoundFile->so-vits-svc-fork) (2.22)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi==0.111.1->so-vits-svc-fork) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.12.0->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.12.0->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.12.0->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0->fastapi==0.111.1->so-vits-svc-fork) (15.0.1)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx->so-vits-svc-fork) (5.29.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->so-vits-svc-fork) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->so-vits-svc-fork) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->so-vits-svc-fork) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->so-vits-svc-fork) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->so-vits-svc-fork) (3.1.3)
# Downloading so_vits_svc_fork-4.2.26-py3-none-any.whl (94 kB)
# Downloading fastapi-0.111.1-py3-none-any.whl (92 kB)
# Downloading lightning-2.5.1.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 27.8 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 166.8 MB/s eta 0:00:00
# Downloading PySimpleGUI_4_foss-4.60.4.1-py3-none-any.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.5/689.5 kB 41.3 MB/s eta 0:00:00
# Downloading setuptools-69.5.1-py3-none-any.whl (894 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 894.6/894.6 kB 46.0 MB/s eta 0:00:00
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 54.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 165.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 167.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 45.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 73.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 144.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 126.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 62.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 154.2 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 58.6 MB/s eta 0:00:00
# Downloading tqdm_joblib-0.0.4-py3-none-any.whl (1.7 kB)
# Downloading cm_time-0.1.2-py3-none-any.whl (7.8 kB)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Downloading fastapi_cli-0.0.7-py3-none-any.whl (10 kB)
# Downloading pebble-5.1.1-py3-none-any.whl (34 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading rich_toolkit-0.14.5-py3-none-any.whl (24 kB)
# Downloading torchcrepe-0.0.23-py3-none-any.whl (72.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 MB 89.3 MB/s eta 0:00:00
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 138.8 MB/s eta 0:00:00
# Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (454 kB)
# Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 172.6 MB/s eta 0:00:00
# Downloading onnxoptimizer-0.3.13-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (678 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 678.1/678.1 kB 40.0 MB/s eta 0:00:00
# Downloading onnxsim-0.4.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 92.8 MB/s eta 0:00:00
# Downloading praat_parselmouth-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 52.3 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 52.7 MB/s eta 0:00:00
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 124.4 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Building wheels for collected packages: pyworld
#   Building wheel for pyworld (pyproject.toml) ... done
#   Created wheel for pyworld: filename=pyworld-0.3.5-cp311-cp311-linux_x86_64.whl size=924300 sha256=9386a61b5439f4bc99b03f4ff7d1d0b6392e703d064b028c00f2bc41ba21ea03
#   Stored in directory: /root/.cache/pip/wheels/26/f0/db/ebcd5cdfe5ad7d229917d3a8db6f18f0cf40f099bf878e294d
# Successfully built pyworld
# Installing collected packages: pysimplegui-4-foss, uvloop, uvicorn, tqdm-joblib, setuptools, python-multipart, python-dotenv, pebble, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, httptools, dnspython, cm-time, watchfiles, tensorboardx, starlette, sounddevice, pyworld, praat-parselmouth, onnx, nvidia-cusparse-cu12, nvidia-cudnn-cu12, lightning-utilities, email_validator, rich-toolkit, resampy, onnxsim, onnxoptimizer, nvidia-cusolver-cu12, fastapi-cli, torchmetrics, fastapi, torchcrepe, pytorch-lightning, lightning, so-vits-svc-fork
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42/42 [so-vits-svc-fork]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed cm-time-0.1.2 dnspython-2.7.0 email_validator-2.2.0 fastapi-0.111.1 fastapi-cli-0.0.7 httptools-0.6.4 lightning-2.5.1.post0 lightning-utilities-0.14.3 numpy-1.26.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 onnx-1.17.0 onnxoptimizer-0.3.13 onnxsim-0.4.36 pebble-5.1.1 praat-parselmouth-0.4.5 pysimplegui-4-foss-4.60.4.1 python-dotenv-1.1.0 python-multipart-0.0.20 pytorch-lightning-2.5.1.post0 pyworld-0.3.5 resampy-0.4.3 rich-toolkit-0.14.5 setuptools-69.5.1 so-vits-svc-fork-4.2.26 sounddevice-0.5.1 starlette-0.37.2 tensorboardx-2.6.2.2 torchcrepe-0.0.23 torchmetrics-1.7.1 tqdm-joblib-0.0.4 uvicorn-0.34.2 uvloop-0.21.0 watchfiles-1.0.5

# %% [markdown]
# ## Training

# %%
#@title Make dataset directory
# !mkdir -p "dataset_raw"

# %%
#!rm -r "dataset_raw"
#!rm -r "dataset/44k"

# %%
#@title Copy your dataset
#@markdown **We assume that your dataset is in your Google Drive's `so-vits-svc-fork/dataset/(speaker_name)` directory.**
DATASET_NAME = "yen-uyen-hau-cung-nhu-y-truyen" #@param {type: "string"}
# !cp -R /content/drive/MyDrive/so-vits-svc-fork/dataset/{DATASET_NAME}/ -t "dataset_raw/"

# %%
#@title Download dataset (Tsukuyomi-chan JVS)
#@markdown You can download this dataset if you don't have your own dataset.
#@markdown Make sure you agree to the license when using this dataset.
#@markdown https://tyc.rei-yumesaki.net/material/corpus/#toc6
# !wget https://tyc.rei-yumesaki.net/files/sozai-tyc-corpus1.zip
# !unzip sozai-tyc-corpus1.zip
# !mv "/content/つくよみちゃんコーパス Vol.1 声優統計コーパス（JVSコーパス準拠）/おまけ：WAV（+12dB増幅＆高音域削減）/WAV（+12dB増幅＆高音域削減）" "dataset_raw/tsukuyomi"

# %%
#@title Automatic preprocessing
# !svc pre-resample
# Out:
# [02:00:28] INFO     [02:00:28] NumExpr defaulting to 12 threads.    ]8;id=12325;file:///usr/local/lib/python3.11/dist-packages/numexpr/utils.py\utils.py]8;;\:]8;id=546364;file:///usr/local/lib/python3.11/dist-packages/numexpr/utils.py#162\162]8;;\
# 2025-05-11 02:00:31.696152: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-11 02:00:31.711803: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746928831.732838    3958 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746928831.739312    3958 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-11 02:00:31.760800: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Preprocessing:  46% 332/715 [00:20<00:02, 145.65it/s][02:00:58] WARNING  [02:00:58]                                   ]8;id=738848;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=614478;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/so_v
#                     its_svc_fork/preprocessing/preprocess_resamp
#                     le.py:62: UserWarning: PySoundFile failed.
#                     Trying audioread instead.
#                       audio, sr = librosa.load(input_path,
#                     sr=sr, mono=True)
#
#            WARNING  [02:00:58]                                   ]8;id=769997;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=322533;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/libr
#                     osa/core/audio.py:184: FutureWarning:
#                     librosa.core.audio.__audioread_load
#                             Deprecated as of librosa version
#                     0.10.0.
#                             It will be removed in librosa
#                     version 1.0.
#                       y, sr_native = __audioread_load(path,
#                     offset, duration, dtype)
#
# Preprocessing:  61% 436/715 [00:20<00:01, 224.62it/s]           WARNING  [02:00:58] Failed to load          ]8;id=538648;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_resample.py\preprocess_resample.py]8;;\:]8;id=241986;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_resample.py#67\67]8;;\
#                     dataset_raw/yen-uyen-hau-cung-nhu-
#                     y-truyen/.DS_Store due to
# Preprocessing: 100% 715/715 [00:21<00:00, 33.79it/s]

# %%
# !svc pre-config
# Out:
# [02:01:15] INFO     [02:01:15] NumExpr defaulting to 12 threads.    ]8;id=283933;file:///usr/local/lib/python3.11/dist-packages/numexpr/utils.py\utils.py]8;;\:]8;id=537307;file:///usr/local/lib/python3.11/dist-packages/numexpr/utils.py#162\162]8;;\
# 2025-05-11 02:01:16.885914: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-11 02:01:16.903353: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746928876.924838    4340 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746928876.931358    4340 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-11 02:01:16.952794: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#   0% 0/714 [00:00<?, ?it/s][02:01:19] WARNING  [02:01:19]                                   ]8;id=777359;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=329314;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/so_v
#                     its_svc_fork/preprocessing/preprocess_flist_
#                     config.py:41: FutureWarning: get_duration()
#                     keyword argument 'filename' has been renamed
#                     to 'path' in version 0.10.0.
#                             This alias will be removed in
#                     version 1.0.
#                       if get_duration(filename=path) < 0.3:
#
# 100% 714/714 [00:00<00:00, 1844.16it/s]
# [02:01:20] INFO     [02:01:20] Writing             ]8;id=826793;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py\preprocess_flist_config.py]8;;\:]8;id=334129;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py#54\54]8;;\
#                     filelists/44k/train.txt
#            INFO     [02:01:20] Writing             ]8;id=176215;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py\preprocess_flist_config.py]8;;\:]8;id=820242;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py#60\60]8;;\
#                     filelists/44k/val.txt
#            INFO     [02:01:20] Writing             ]8;id=998532;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py\preprocess_flist_config.py]8;;\:]8;id=604899;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py#64\64]8;;\
#                     filelists/44k/test.txt
#            INFO     [02:01:20] Writing             ]8;id=673341;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py\preprocess_flist_config.py]8;;\:]8;id=244185;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py#83\83]8;;\
#                     configs/44k/config.json

# %%
#@title Export configs file
#@markdown This assumes that you want to save the **config.json** on the default location. There will be also a backup file created in case the action is done accidentally.!cp configs/44k/config.json configs/44k/config.bkp.json!cp drive/MyDrive/so-vits-svc-fork/config.json configs/44k

# %%
#@title Import configs file (Optional Step, NOT REQUIRED)
#@markdown This assumes that you are saving the **config.json** on the default location. There will be also a backup file created in case the action is done accidentally.!cp drive/MyDrive/so-vits-svc-fork/config.json drive/MyDrive/so-vits-svc-fork/config.bkp.json!cp configs/44k/config.json drive/MyDrive/so-vits-svc-fork

# %%
F0_METHOD = "crepe" #@param ["crepe", "crepe-tiny", "parselmouth", "dio", "harvest"]
# !svc pre-hubert -fm {F0_METHOD}
# Out:
# [02:02:29] INFO     [02:02:29] NumExpr defaulting to 12 threads.    ]8;id=390531;file:///usr/local/lib/python3.11/dist-packages/numexpr/utils.py\utils.py]8;;\:]8;id=915512;file:///usr/local/lib/python3.11/dist-packages/numexpr/utils.py#162\162]8;;\
# 2025-05-11 02:02:30.511356: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-11 02:02:30.529234: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746928950.551007    4708 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746928950.557584    4708 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-11 02:02:30.579497: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [02:02:33] INFO     [02:02:33] n_jobs automatically  ]8;id=759970;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_hubert_f0.py\preprocess_hubert_f0.py]8;;\:]8;id=250021;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_hubert_f0.py#142\142]8;;\
#                     set to 5, memory: 23034 MiB
# 2025-05-11 02:02:38.943572: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746928958.964362    4794 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746928958.970712    4794 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-11 02:02:38.987110: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-11 02:02:38.987110: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746928959.008075    4795 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746928959.008166    4796 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746928959.014440    4795 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1746928959.014521    4796 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-11 02:02:39.022835: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746928959.043887    4801 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746928959.050298    4801 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-11 02:02:39.078810: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746928959.100129    4802 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746928959.106520    4802 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json: 100% 1.39k/1.39k [00:00<00:00, 9.12MB/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# [02:02:42] WARNING  [02:02:42] Xet Storage is enabled for  ]8;id=196930;file:///usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py\file_download.py]8;;\:]8;id=690137;file:///usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py#1670\1670]8;;\
#                     this repo, but the 'hf_xet' package is
#                     not installed. Falling back to regular
#                     HTTP download. For better performance,
#                     install the package with: `pip install
#                     huggingface_hub[hf_xet]` or `pip
#                     install hf_xet`
# pytorch_model.bin: 100% 378M/378M [00:01<00:00, 304MB/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# [02:02:44] WARNING  [02:02:44] Xet Storage is enabled for  ]8;id=541278;file:///usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py\file_download.py]8;;\:]8;id=554535;file:///usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py#1670\1670]8;;\
#                     this repo, but the 'hf_xet' package is
#                     not installed. Falling back to regular
#                     HTTP download. For better performance,
#                     install the package with: `pip install
#                     huggingface_hub[hf_xet]` or `pip
#                     install hf_xet`
#   0% 0/143 [00:00<?, ?it/s]
#   0% 0/143 [00:00<?, ?it/s]
#
#   0% 0/143 [00:00<?, ?it/s]
#
#
#   0% 0/143 [00:00<?, ?it/s]
#
#
#
# model.safetensors: 100% 378M/378M [00:02<00:00, 185MB/s]
# [02:02:48] INFO     [02:02:48] F0 inference time:       2.769s, RTF:   ]8;id=111357;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=581223;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     1.923
# [02:02:48] INFO     [02:02:48] F0 inference time:       3.139s, RTF:   ]8;id=992370;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=568692;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     2.675
# [02:02:48] INFO     [02:02:48] F0 inference time:       3.160s, RTF:   ]8;id=335121;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=627335;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.527
# [02:02:49] INFO     [02:02:49] HuBERT inference time  : 0.152s,     ]8;id=106255;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=467224;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.129
# [02:02:49] INFO     [02:02:49] HuBERT inference time  : 0.157s,     ]8;id=421168;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=506392;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.109
# [02:02:49] INFO     [02:02:49] HuBERT inference time  : 0.096s,     ]8;id=606518;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=464254;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.016
#            WARNING  [02:02:49]                                   ]8;id=720945;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=773892;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/torc
#                     h/functional.py:709: UserWarning: stft with
#                     return_complex=False is deprecated. In a
#                     future pytorch release, stft will return
#                     complex tensors for all inputs, and
#                     return_complex=False will raise an error.
#                     Note: you can still call torch.view_as_real
#                     on the complex output to recover the old
#                     return format. (Triggered internally at
#                     /pytorch/aten/src/ATen/native/SpectralOps.cp
#                     p:873.)
#                       return _VF.stft(  # type:
#                     ignore[attr-defined]
#
#            WARNING  [02:02:49]                                   ]8;id=424217;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=695934;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/torc
#                     h/functional.py:709: UserWarning: stft with
#                     return_complex=False is deprecated. In a
#                     future pytorch release, stft will return
#                     complex tensors for all inputs, and
#                     return_complex=False will raise an error.
#                     Note: you can still call torch.view_as_real
#                     on the complex output to recover the old
#                     return format. (Triggered internally at
#                     /pytorch/aten/src/ATen/native/SpectralOps.cp
#                     p:873.)
#                       return _VF.stft(  # type:
#                     ignore[attr-defined]
#
#            WARNING  [02:02:49]                                   ]8;id=782085;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=399479;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/torc
#                     h/functional.py:709: UserWarning: stft with
#                     return_complex=False is deprecated. In a
#                     future pytorch release, stft will return
#                     complex tensors for all inputs, and
#                     return_complex=False will raise an error.
#                     Note: you can still call torch.view_as_real
#                     on the complex output to recover the old
#                     return format. (Triggered internally at
#                     /pytorch/aten/src/ATen/native/SpectralOps.cp
#                     p:873.)
#                       return _VF.stft(  # type:
#                     ignore[attr-defined]
#
#
#
#   1% 1/143 [00:04<10:09,  4.29s/it]
#   1% 1/143 [00:04<10:10,  4.30s/it]
#
#
#   1% 1/143 [00:04<10:10,  4.30s/it][02:02:49] INFO     [02:02:49] F0 inference time:       3.051s, RTF:   ]8;id=724812;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=867399;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.514
#            INFO     [02:02:49] HuBERT inference time  : 0.095s,     ]8;id=231942;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=360856;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.016
#            WARNING  [02:02:49]                                   ]8;id=822425;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=224122;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/torc
#                     h/functional.py:709: UserWarning: stft with
#                     return_complex=False is deprecated. In a
#                     future pytorch release, stft will return
#                     complex tensors for all inputs, and
#                     return_complex=False will raise an error.
#                     Note: you can still call torch.view_as_real
#                     on the complex output to recover the old
#                     return format. (Triggered internally at
#                     /pytorch/aten/src/ATen/native/SpectralOps.cp
#                     p:873.)
#                       return _VF.stft(  # type:
#                     ignore[attr-defined]
#
#
#
#
#
#   1% 1/142 [00:04<10:42,  4.55s/it][02:02:49] INFO     [02:02:49] F0 inference time:       3.806s, RTF:   ]8;id=118866;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=459459;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.310
#            INFO     [02:02:49] HuBERT inference time  : 0.123s,     ]8;id=848095;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=294204;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.010
#            WARNING  [02:02:49]                                   ]8;id=543568;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=34320;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/torc
#                     h/functional.py:709: UserWarning: stft with
#                     return_complex=False is deprecated. In a
#                     future pytorch release, stft will return
#                     complex tensors for all inputs, and
#                     return_complex=False will raise an error.
#                     Note: you can still call torch.view_as_real
#                     on the complex output to recover the old
#                     return format. (Triggered internally at
#                     /pytorch/aten/src/ATen/native/SpectralOps.cp
#                     p:873.)
#                       return _VF.stft(  # type:
#                     ignore[attr-defined]
#
#   1% 1/143 [00:04<11:38,  4.92s/it]           INFO     [02:02:49] F0 inference time:       0.112s, RTF:   ]8;id=146555;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=237070;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.187
#            INFO     [02:02:49] HuBERT inference time  : 0.024s,     ]8;id=282579;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=391025;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.039
#   1% 2/143 [00:05<04:58,  2.12s/it]           INFO     [02:02:49] F0 inference time:       0.779s, RTF:   ]8;id=12153;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=842685;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.078
#            INFO     [02:02:49] HuBERT inference time  : 0.020s,     ]8;id=735081;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=624194;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#
#
#   1% 2/143 [00:05<05:23,  2.29s/it][02:02:50] INFO     [02:02:50] F0 inference time:       1.437s, RTF:   ]8;id=403169;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=261924;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.091
#            INFO     [02:02:50] HuBERT inference time  : 0.019s,     ]8;id=162472;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=962432;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
# [02:02:50] INFO     [02:02:50] F0 inference time:       0.731s, RTF:   ]8;id=901588;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=376958;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.114
#            INFO     [02:02:50] HuBERT inference time  : 0.024s,     ]8;id=618513;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=106075;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#
#
#
#   2% 3/143 [00:05<03:33,  1.52s/it][02:02:51] INFO     [02:02:51] F0 inference time:       0.332s, RTF:   ]8;id=426758;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=53790;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.104
# [02:02:51] INFO     [02:02:51] F0 inference time:       1.894s, RTF:   ]8;id=253034;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=744759;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.091
#            INFO     [02:02:51] HuBERT inference time  : 0.019s,     ]8;id=108055;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=234965;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.006
#            INFO     [02:02:51] HuBERT inference time  : 0.020s,     ]8;id=465463;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=539648;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#
#   2% 3/143 [00:06<03:48,  1.63s/it][02:02:51] INFO     [02:02:51] F0 inference time:       1.730s, RTF:   ]8;id=850687;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=386332;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.103
#            INFO     [02:02:51] HuBERT inference time  : 0.019s,     ]8;id=743467;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=369666;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#   1% 2/143 [00:06<07:03,  3.00s/it]
#
#
#
#   1% 2/142 [00:06<06:57,  2.98s/it]           INFO     [02:02:51] F0 inference time:       0.183s, RTF:   ]8;id=406547;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=608487;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.131
#            INFO     [02:02:51] HuBERT inference time  : 0.022s,     ]8;id=31209;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=976227;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.016
#
#   2% 3/143 [00:06<04:04,  1.74s/it]           INFO     [02:02:51] F0 inference time:       0.222s, RTF:   ]8;id=156200;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=963630;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.213
#            INFO     [02:02:51] HuBERT inference time  : 0.026s,     ]8;id=498436;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=502389;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.025
#
#
#
#
#   2% 3/142 [00:06<04:03,  1.75s/it]           INFO     [02:02:51] F0 inference time:       0.167s, RTF:   ]8;id=568266;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=51863;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.266
#            INFO     [02:02:51] HuBERT inference time  : 0.020s,     ]8;id=964451;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=338627;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.032
#
#   3% 4/143 [00:06<02:37,  1.14s/it]           INFO     [02:02:51] F0 inference time:       0.804s, RTF:   ]8;id=158026;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=174367;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.110
#            INFO     [02:02:51] HuBERT inference time  : 0.019s,     ]8;id=872166;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=910218;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#
#
#   3% 4/143 [00:07<03:05,  1.33s/it]           INFO     [02:02:51] F0 inference time:       0.271s, RTF:   ]8;id=897207;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=11240;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.082
#            INFO     [02:02:51] HuBERT inference time  : 0.020s,     ]8;id=963678;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=314050;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.006
#
#   3% 5/143 [00:07<01:56,  1.18it/s][02:02:52] INFO     [02:02:52] F0 inference time:       1.294s, RTF:   ]8;id=329689;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=969366;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.099
#            INFO     [02:02:52] HuBERT inference time  : 0.019s,     ]8;id=423211;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=605056;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#   3% 4/143 [00:07<03:25,  1.48s/it][02:02:52] INFO     [02:02:52] F0 inference time:       2.333s, RTF:   ]8;id=168713;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=127857;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.091
#            INFO     [02:02:52] HuBERT inference time  : 0.020s,     ]8;id=40128;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=338002;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
# [02:02:52] INFO     [02:02:52] F0 inference time:       0.601s, RTF:   ]8;id=384303;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=319455;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.114
#            INFO     [02:02:52] HuBERT inference time  : 0.025s,     ]8;id=659010;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=938833;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.005
#
#
#
#   3% 5/143 [00:07<02:31,  1.10s/it][02:02:52] INFO     [02:02:52] F0 inference time:       1.071s, RTF:   ]8;id=314118;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=512011;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.091
#
#
#   2% 3/143 [00:07<05:42,  2.45s/it]           INFO     [02:02:52] HuBERT inference time  : 0.020s,     ]8;id=303029;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=211094;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#            INFO     [02:02:52] F0 inference time:       0.562s, RTF:   ]8;id=481492;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=315307;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.112
#            INFO     [02:02:52] HuBERT inference time  : 0.023s,     ]8;id=654319;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=367027;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.005
#
#
#
#
#   3% 5/143 [00:07<02:42,  1.18s/it][02:02:52] INFO     [02:02:52] F0 inference time:       0.772s, RTF:   ]8;id=388762;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=300981;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.111
#            INFO     [02:02:52] HuBERT inference time  : 0.019s,     ]8;id=679302;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=236704;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#   4% 6/143 [00:08<01:55,  1.18it/s][02:02:53] INFO     [02:02:53] F0 inference time:       0.569s, RTF:   ]8;id=729361;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=855006;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.086
#            INFO     [02:02:53] HuBERT inference time  : 0.021s,     ]8;id=329681;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=603005;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#
#
#   4% 6/143 [00:08<02:11,  1.04it/s][02:02:53] INFO     [02:02:53] F0 inference time:       0.787s, RTF:   ]8;id=790121;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=359667;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.103
#            INFO     [02:02:53] HuBERT inference time  : 0.021s,     ]8;id=463288;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=332235;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#
#   3% 4/143 [00:08<04:13,  1.82s/it][02:02:53] INFO     [02:02:53] F0 inference time:       0.817s, RTF:   ]8;id=223433;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=388477;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.115
#            INFO     [02:02:53] HuBERT inference time  : 0.020s,     ]8;id=633171;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=50815;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
# [02:02:53] INFO     [02:02:53] F0 inference time:       0.832s, RTF:   ]8;id=546129;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=594309;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.116
#
#
#
#
#   4% 5/142 [00:08<02:57,  1.29s/it]           INFO     [02:02:53] HuBERT inference time  : 0.020s,     ]8;id=446674;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=965190;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
# [02:02:53] INFO     [02:02:53] F0 inference time:       0.791s, RTF:   ]8;id=91553;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=113651;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.110
#            INFO     [02:02:53] HuBERT inference time  : 0.021s,     ]8;id=755996;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=253358;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#   4% 6/143 [00:08<02:28,  1.09s/it]
#   5% 7/143 [00:08<01:55,  1.17it/s]           INFO     [02:02:53] F0 inference time:       0.235s, RTF:   ]8;id=705016;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=872758;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.103
#            INFO     [02:02:53] HuBERT inference time  : 0.021s,     ]8;id=45876;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=667851;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.009
#   5% 7/143 [00:09<01:52,  1.21it/s][02:02:54] INFO     [02:02:54] F0 inference time:       0.525s, RTF:   ]8;id=705050;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=299721;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.084
#            INFO     [02:02:54] HuBERT inference time  : 0.022s,     ]8;id=194860;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=623425;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#
#   3% 5/143 [00:09<03:10,  1.38s/it][02:02:54] INFO     [02:02:54] F0 inference time:       0.451s, RTF:   ]8;id=826843;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=488492;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.081
#            INFO     [02:02:54] HuBERT inference time  : 0.022s,     ]8;id=374911;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=62718;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#
#   6% 8/143 [00:09<01:41,  1.33it/s][02:02:54] INFO     [02:02:54] F0 inference time:       0.299s, RTF:   ]8;id=430568;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=642108;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.103
#            INFO     [02:02:54] HuBERT inference time  : 0.020s,     ]8;id=595201;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=775133;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.007
#   6% 8/143 [00:09<01:31,  1.47it/s]           INFO     [02:02:54] F0 inference time:       0.351s, RTF:   ]8;id=56588;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=303821;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.124
#            INFO     [02:02:54] HuBERT inference time  : 0.020s,     ]8;id=830774;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=367278;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.007
#
#
#   4% 6/143 [00:09<02:25,  1.06s/it]           INFO     [02:02:54] F0 inference time:       0.559s, RTF:   ]8;id=658186;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=325728;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.112
#            INFO     [02:02:54] HuBERT inference time  : 0.021s,     ]8;id=645520;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=818271;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#
#   6% 9/143 [00:10<01:35,  1.40it/s]           INFO     [02:02:54] F0 inference time:       0.373s, RTF:   ]8;id=268645;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=957526;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.075
#            INFO     [02:02:54] HuBERT inference time  : 0.016s,     ]8;id=497915;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=419202;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#
#   5% 7/143 [00:10<01:56,  1.17it/s][02:02:55] INFO     [02:02:55] F0 inference time:       1.573s, RTF:   ]8;id=198811;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=169661;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.109
#            INFO     [02:02:55] HuBERT inference time  : 0.020s,     ]8;id=718319;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=795073;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#
#
#   4% 6/142 [00:10<03:18,  1.46s/it][02:02:55] INFO     [02:02:55] F0 inference time:       0.681s, RTF:   ]8;id=995299;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=543057;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.120
#            INFO     [02:02:55] HuBERT inference time  : 0.021s,     ]8;id=729324;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=911713;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#
#   7% 10/143 [00:10<01:37,  1.37it/s][02:02:55] INFO     [02:02:55] F0 inference time:       2.539s, RTF:   ]8;id=302422;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=637355;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.104
#            INFO     [02:02:55] HuBERT inference time  : 0.020s,     ]8;id=486081;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=563074;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#            INFO     [02:02:55] F0 inference time:       0.538s, RTF:   ]8;id=207596;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=702940;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.101
# [02:02:56] INFO     [02:02:56] HuBERT inference time  : 0.022s,     ]8;id=535156;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=969457;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#
#
#
#
#   5% 7/142 [00:11<02:40,  1.19s/it]
#
#
#   5% 7/143 [00:11<03:29,  1.54s/it]           INFO     [02:02:56] F0 inference time:       0.272s, RTF:   ]8;id=349390;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=600517;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.117
#            INFO     [02:02:56] HuBERT inference time  : 0.019s,     ]8;id=96472;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=863729;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.008
#
#
#
#
#   6% 8/142 [00:11<02:02,  1.10it/s][02:02:56] INFO     [02:02:56] F0 inference time:       1.399s, RTF:   ]8;id=899003;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=145371;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.095
# [02:02:56] INFO     [02:02:56] F0 inference time:       0.739s, RTF:   ]8;id=953707;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=960856;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.102
#            INFO     [02:02:56] HuBERT inference time  : 0.019s,     ]8;id=662244;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=60027;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#            INFO     [02:02:56] HuBERT inference time  : 0.020s,     ]8;id=674239;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=296967;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#   8% 11/143 [00:11<01:40,  1.31it/s]           INFO     [02:02:56] F0 inference time:       0.159s, RTF:   ]8;id=65202;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=789947;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.127
#            INFO     [02:02:56] HuBERT inference time  : 0.019s,     ]8;id=643989;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=321430;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.015
#
#
#   6% 8/143 [00:11<02:26,  1.08s/it]
#
#
#
#   6% 9/142 [00:11<01:32,  1.44it/s]           INFO     [02:02:56] F0 inference time:       0.187s, RTF:   ]8;id=844510;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=132135;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.101
#            INFO     [02:02:56] HuBERT inference time  : 0.019s,     ]8;id=27763;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=536068;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.010
# [02:02:56] INFO     [02:02:56] F0 inference time:       2.441s, RTF:   ]8;id=93932;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=140842;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.101
#
#
#   6% 9/143 [00:11<01:49,  1.22it/s]           INFO     [02:02:56] HuBERT inference time  : 0.020s,     ]8;id=151797;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=334041;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
# [02:02:56] INFO     [02:02:56] F0 inference time:       0.780s, RTF:   ]8;id=351615;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=917739;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.086
#            INFO     [02:02:56] HuBERT inference time  : 0.020s,     ]8;id=1765;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=748282;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#            INFO     [02:02:56] F0 inference time:       0.290s, RTF:   ]8;id=35506;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=890593;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.103
# ...
#                     0.094
#            INFO     [02:05:16] HuBERT inference time  : 0.017s,     ]8;id=985039;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=832760;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#  94% 134/143 [02:31<00:08,  1.11it/s]           INFO     [02:05:16] F0 inference time:       0.171s, RTF:   ]8;id=395800;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=598099;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.077
#            INFO     [02:05:16] HuBERT inference time  : 0.019s,     ]8;id=953827;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=704483;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.009
#
#  94% 135/143 [02:31<00:05,  1.44it/s][02:05:16] INFO     [02:05:16] F0 inference time:       1.011s, RTF:   ]8;id=620932;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=906475;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.079
#            INFO     [02:05:16] HuBERT inference time  : 0.019s,     ]8;id=970041;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=909051;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#  95% 136/143 [02:31<00:09,  1.40s/it][02:05:16] INFO     [02:05:16] F0 inference time:       4.454s, RTF:   ]8;id=590516;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=31313;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.080
#            INFO     [02:05:16] HuBERT inference time  : 0.019s,     ]8;id=946336;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=279461;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.000
#
#
#
#  98% 140/143 [02:32<00:05,  1.75s/it][02:05:17] INFO     [02:05:17] F0 inference time:       0.488s, RTF:   ]8;id=966030;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=212933;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.104
#            INFO     [02:05:17] HuBERT inference time  : 0.021s,     ]8;id=333147;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=164711;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.005
#  96% 137/143 [02:32<00:06,  1.14s/it]           INFO     [02:05:17] F0 inference time:       0.183s, RTF:   ]8;id=98262;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=597663;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.078
#            INFO     [02:05:17] HuBERT inference time  : 0.019s,     ]8;id=594946;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=135169;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.008
#  97% 138/143 [02:32<00:04,  1.15it/s][02:05:17] INFO     [02:05:17] F0 inference time:       1.079s, RTF:   ]8;id=294328;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=777225;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.086
#            INFO     [02:05:17] HuBERT inference time  : 0.019s,     ]8;id=744852;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=48434;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
# [02:05:17] INFO     [02:05:17] F0 inference time:       0.471s, RTF:   ]8;id=89550;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=712470;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.077
#
#  95% 136/143 [02:32<00:05,  1.19it/s]           INFO     [02:05:17] HuBERT inference time  : 0.023s,     ]8;id=275162;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=182727;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#
#
#
#  99% 141/143 [02:32<00:02,  1.39s/it][02:05:18] INFO     [02:05:18] F0 inference time:       0.669s, RTF:   ]8;id=217106;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=429290;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.097
#            INFO     [02:05:18] HuBERT inference time  : 0.009s,     ]8;id=459994;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=207823;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#
#  99% 142/143 [02:33<00:01,  1.19s/it][02:05:18] INFO     [02:05:18] F0 inference time:       1.137s, RTF:   ]8;id=735029;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=925465;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.091
#            INFO     [02:05:18] HuBERT inference time  : 0.020s,     ]8;id=662462;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=210416;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#  97% 139/143 [02:33<00:03,  1.00it/s]           INFO     [02:05:18] F0 inference time:       0.400s, RTF:   ]8;id=470366;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=246079;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.104
#            INFO     [02:05:18] HuBERT inference time  : 0.021s,     ]8;id=978546;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=775679;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.005
#
#
#
# 100% 143/143 [02:33<00:00,  1.08s/it]
# [02:05:19] INFO     [02:05:19] F0 inference time:       2.032s, RTF:   ]8;id=377087;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=829214;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.081
#            INFO     [02:05:19] HuBERT inference time  : 0.019s,     ]8;id=549763;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=970682;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#  96% 137/143 [02:34<00:07,  1.24s/it][02:05:20] INFO     [02:05:20] F0 inference time:       0.353s, RTF:   ]8;id=319376;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=522455;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.084
#            INFO     [02:05:20] HuBERT inference time  : 0.011s,     ]8;id=480696;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=839401;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#  97% 138/143 [02:35<00:04,  1.01it/s][02:05:20] INFO     [02:05:20] F0 inference time:       1.648s, RTF:   ]8;id=84534;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=59310;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.079
#            INFO     [02:05:20] HuBERT inference time  : 0.021s,     ]8;id=437833;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=150199;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#  98% 140/143 [02:35<00:03,  1.23s/it]           INFO     [02:05:20] F0 inference time:       0.357s, RTF:   ]8;id=614138;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=491213;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.075
#            INFO     [02:05:20] HuBERT inference time  : 0.020s,     ]8;id=306576;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=571962;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#  99% 141/143 [02:35<00:01,  1.01it/s][02:05:21] INFO     [02:05:21] F0 inference time:       0.385s, RTF:   ]8;id=290568;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=837918;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.073
#            INFO     [02:05:21] HuBERT inference time  : 0.020s,     ]8;id=225429;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=458908;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#  99% 142/143 [02:36<00:00,  1.21it/s]           INFO     [02:05:21] F0 inference time:       0.125s, RTF:   ]8;id=480263;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=539951;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.078
#            INFO     [02:05:21] HuBERT inference time  : 0.020s,     ]8;id=208007;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=661520;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.012
# 100% 143/143 [02:36<00:00,  1.10s/it]
# [02:05:23] INFO     [02:05:23] F0 inference time:       3.128s, RTF:   ]8;id=676192;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=506522;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.075
#            INFO     [02:05:23] HuBERT inference time  : 0.020s,     ]8;id=904662;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=166410;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.000
#
#  97% 139/143 [02:38<00:06,  1.71s/it][02:05:25] INFO     [02:05:25] F0 inference time:       1.754s, RTF:   ]8;id=493042;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=226866;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.074
#            INFO     [02:05:25] HuBERT inference time  : 0.020s,     ]8;id=152617;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=172453;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#  98% 140/143 [02:40<00:05,  1.76s/it]           INFO     [02:05:25] F0 inference time:       0.096s, RTF:   ]8;id=798300;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=492441;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.093
#            INFO     [02:05:25] HuBERT inference time  : 0.020s,     ]8;id=947835;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=709240;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.019
#
#  99% 141/143 [02:40<00:02,  1.28s/it][02:05:26] INFO     [02:05:26] F0 inference time:       0.509s, RTF:   ]8;id=654986;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=254358;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.074
#            INFO     [02:05:26] HuBERT inference time  : 0.020s,     ]8;id=786235;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=554445;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#  99% 142/143 [02:41<00:01,  1.07s/it]           INFO     [02:05:26] F0 inference time:       0.102s, RTF:   ]8;id=957333;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=295205;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.079
#            INFO     [02:05:26] HuBERT inference time  : 0.019s,     ]8;id=925172;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=97828;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.015
#
# 100% 143/143 [02:41<00:00,  1.13s/it]

# %%
#@title Train
# %pip install matplotlib==3.5.3
# %load_ext tensorboard
# %tensorboard --logdir drive/MyDrive/so-vits-svc-fork/logs/44k
# !svc train --model-path drive/MyDrive/so-vits-svc-fork/logs/44k

# %% [markdown]
# ## Training Cluster model

# %%
# !svc train-cluster --output-path drive/MyDrive/so-vits-svc-fork/logs/44k/kmeans.pt

# %% [markdown]
# ## Inference

# %%
#@title Get the author's voice as a source
import random
NAME = str(random.randint(1, 49))
TYPE = "fsd50k" #@param ["", "digit", "dog", "fsd50k"]
CUSTOM_FILEPATH = "" #@param {type: "string"}
if CUSTOM_FILEPATH != "":
    NAME = CUSTOM_FILEPATH
else:
    # it is extremely difficult to find a voice that can download from the internet directly
    if TYPE == "dog":
        # !wget -N f"https://huggingface.co/datasets/437aewuh/dog-dataset/resolve/main/dogs/dogs_{NAME:.0000}.wav" -O {NAME}.wav
    elif TYPE == "digit":
        # george, jackson, lucas, nicolas, ...
        # !wget -N f"https://github.com/Jakobovski/free-spoken-digit-dataset/raw/master/recordings/0_george_{NAME}.wav" -O {NAME}.wav
    elif TYPE == "fsd50k":
        # !wget -N f"https://huggingface.co/datasets/Fhrozen/FSD50k/blob/main/clips/dev/{10000+int(NAME)}.wav" -O {NAME}.wav
    else:
        # !wget -N f"https://zunko.jp/sozai/utau/voice_{"kiritan" if NAME < 25 else "itako"}{NAME % 5 + 1}.wav" -O {NAME}.wav
from IPython.display import Audio, display
display(Audio(f"{NAME}.wav"))

# %%
#@title Use trained model
#@markdown **Put your .wav file in `so-vits-svc-fork/audio` directory**
from IPython.display import Audio, display
# !svc infer drive/MyDrive/so-vits-svc-fork/audio/{NAME}.wav -m drive/MyDrive/so-vits-svc-fork/logs/44k/ -c drive/MyDrive/so-vits-svc-fork/logs/44k/config.json
display(Audio(f"drive/MyDrive/so-vits-svc-fork/audio/{NAME}.out.wav", autoplay=True))

# %%
##@title Use trained model (with cluster)
# !svc infer {NAME}.wav -s speaker -r 0.1 -m drive/MyDrive/so-vits-svc-fork/logs/44k/ -c drive/MyDrive/so-vits-svc-fork/logs/44k/config.json -k drive/MyDrive/so-vits-svc-fork/logs/44k/kmeans.pt
display(Audio(f"{NAME}.out.wav", autoplay=True))

# %% [markdown]
# ### Pretrained models

# %%
#@title https://huggingface.co/TachibanaKimika/so-vits-svc-4.0-models/tree/main
# !wget -N "https://huggingface.co/TachibanaKimika/so-vits-svc-4.0-models/resolve/main/riri/G_riri_220.pth"
# !wget -N "https://huggingface.co/TachibanaKimika/so-vits-svc-4.0-models/resolve/main/riri/config.json"

# %%
# !svc infer {NAME}.wav -c config.json -m G_riri_220.pth
display(Audio(f"{NAME}.out.wav", autoplay=True))

# %%
#@title https://huggingface.co/therealvul/so-vits-svc-4.0/tree/main
# !wget -N "https://huggingface.co/therealvul/so-vits-svc-4.0/resolve/main/Pinkie%20(speaking%20sep)/G_166400.pth"
# !wget -N "https://huggingface.co/therealvul/so-vits-svc-4.0/resolve/main/Pinkie%20(speaking%20sep)/config.json"

# %%
# !svc infer {NAME}.wav --speaker "Pinkie {neutral}" -c config.json -m G_166400.pth
display(Audio(f"{NAME}.out.wav", autoplay=True))
