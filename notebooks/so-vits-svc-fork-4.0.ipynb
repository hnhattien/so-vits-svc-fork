# %% [markdown]
# ## Before training
#
# This program saves the last 3 generations of models to Google Drive. Since 1 generation of models is >1GB, you should have at least 3GB of free space in Google Drive. If you do not have such free space, it is recommended to create another Google Account.
#
# Training requires >10GB VRAM. (T4 should be enough) Inference does not require such a lot of VRAM.

# %% [markdown]
# ## Installation

# %%
#@title Check GPU
# !nvidia-smi
# Out:
# Sun May 11 01:56:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   36C    P8             11W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
#@title Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Install dependencies
#@markdown pip may fail to resolve dependencies and raise ERROR, but it can be ignored.
# !python -m pip install -U pip wheel
# %pip install -U ipython
#@markdown Branch (for development)
BRANCH = "none" #@param {"type": "string"}
if BRANCH == "none":
    # %pip install -U so-vits-svc-fork
else:
    # %pip install -U git+https://github.com/34j/so-vits-svc-fork.git@{BRANCH}
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (0.45.1)
# Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.6 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.1.1
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (7.34.0)
# Collecting ipython
#   Downloading ipython-9.2.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython) (4.4.2)
# Collecting ipython-pygments-lexers (from ipython)
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.16 (from ipython)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.11/dist-packages (from ipython) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from ipython) (2.19.1)
# Collecting stack_data (from ipython)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing_extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from ipython) (4.13.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython) (0.7.0)
# Collecting executing>=1.2.0 (from stack_data->ipython)
#   Downloading executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython)
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading ipython-9.2.0-py3-none-any.whl (604 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.3/604.3 kB 20.0 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.1 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Installing collected packages: pure-eval, traitlets, jedi, ipython-pygments-lexers, executing, asttokens, stack_data, ipython
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [ipython]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 9.2.0 which is incompatible.
# Successfully installed asttokens-3.0.0 executing-2.2.0 ipython-9.2.0 ipython-pygments-lexers-1.1.1 jedi-0.19.2 pure-eval-0.2.3 stack_data-0.6.3 traitlets-5.14.3
# Collecting so-vits-svc-fork
#   Downloading so_vits_svc_fork-4.2.26-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: SoundFile in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (0.13.1)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (8.1.8)
# Collecting cm-time>=0.1.2 (from so-vits-svc-fork)
#   Downloading cm_time-0.1.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting fastapi==0.111.1 (from so-vits-svc-fork)
#   Downloading fastapi-0.111.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (0.11.0)
# Collecting lightning<3.0.0,>=2.0.1 (from so-vits-svc-fork)
#   Downloading lightning-2.5.1.post0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (3.10.0)
# Collecting numpy<2.0.0,>=1.26.4 (from so-vits-svc-fork)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting onnx (from so-vits-svc-fork)
#   Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting onnxoptimizer (from so-vits-svc-fork)
#   Downloading onnxoptimizer-0.3.13-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting onnxsim (from so-vits-svc-fork)
#   Downloading onnxsim-0.4.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting pebble>=5.0 (from so-vits-svc-fork)
#   Downloading pebble-5.1.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting praat-parselmouth (from so-vits-svc-fork)
#   Downloading praat_parselmouth-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Collecting pysimplegui-4-foss<5.0.0.0,>=4.60.4.1 (from so-vits-svc-fork)
#   Downloading PySimpleGUI_4_foss-4.60.4.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyworld (from so-vits-svc-fork)
#   Downloading pyworld-0.3.5.tar.gz (261 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (13.9.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (1.15.2)
# Collecting setuptools<70.0.0,>=69.5.1 (from so-vits-svc-fork)
#   Downloading setuptools-69.5.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting sounddevice (from so-vits-svc-fork)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (2.18.0)
# Collecting tensorboardx (from so-vits-svc-fork)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: torch<3,>=2 in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (2.6.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (2.6.0+cu124)
# Collecting torchcrepe>=0.0.17 (from so-vits-svc-fork)
#   Downloading torchcrepe-0.0.23-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (4.67.1)
# Collecting tqdm-joblib<0.0.5,>=0.0.4 (from so-vits-svc-fork)
#   Downloading tqdm_joblib-0.0.4-py3-none-any.whl.metadata (269 bytes)
# Requirement already satisfied: transformers<5.0.0,>=4.28.1 in /usr/local/lib/python3.11/dist-packages (from so-vits-svc-fork) (4.51.3)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi==0.111.1->so-vits-svc-fork)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from fastapi==0.111.1->so-vits-svc-fork) (2.11.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi==0.111.1->so-vits-svc-fork) (4.13.2)
# Collecting fastapi-cli>=0.0.2 (from fastapi==0.111.1->so-vits-svc-fork)
#   Downloading fastapi_cli-0.0.7-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from fastapi==0.111.1->so-vits-svc-fork) (0.28.1)
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.11/dist-packages (from fastapi==0.111.1->so-vits-svc-fork) (3.1.6)
# Collecting python-multipart>=0.0.7 (from fastapi==0.111.1->so-vits-svc-fork)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting email_validator>=2.0.0 (from fastapi==0.111.1->so-vits-svc-fork)
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting uvicorn>=0.12.0 (from uvicorn[standard]>=0.12.0->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (2025.3.2)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning<3.0.0,>=2.0.1->so-vits-svc-fork)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.11/dist-packages (from lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (24.2)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning<3.0.0,>=2.0.1->so-vits-svc-fork)
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting pytorch-lightning (from lightning<3.0.0,>=2.0.1->so-vits-svc-fork)
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (3.11.15)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.111.1->so-vits-svc-fork) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.111.1->so-vits-svc-fork) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.111.1->so-vits-svc-fork) (0.4.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from starlette<0.38.0,>=0.37.2->fastapi==0.111.1->so-vits-svc-fork) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi==0.111.1->so-vits-svc-fork) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi==0.111.1->so-vits-svc-fork) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (3.4.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2->so-vits-svc-fork)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->so-vits-svc-fork) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2->so-vits-svc-fork) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.28.1->so-vits-svc-fork) (0.30.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.28.1->so-vits-svc-fork) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.28.1->so-vits-svc-fork) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.28.1->so-vits-svc-fork) (0.5.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.1->so-vits-svc-fork) (1.20.0)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.11/dist-packages (from fastapi-cli>=0.0.2->fastapi==0.111.1->so-vits-svc-fork) (0.15.3)
# Collecting rich-toolkit>=0.11.1 (from fastapi-cli>=0.0.2->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading rich_toolkit-0.14.5-py3-none-any.whl.metadata (999 bytes)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->fastapi==0.111.1->so-vits-svc-fork) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->fastapi==0.111.1->so-vits-svc-fork) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.23.0->fastapi==0.111.1->so-vits-svc-fork) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.11.2->fastapi==0.111.1->so-vits-svc-fork) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.1->so-vits-svc-fork) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->so-vits-svc-fork) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->so-vits-svc-fork) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->so-vits-svc-fork) (0.1.2)
# Collecting resampy (from torchcrepe>=0.0.17->so-vits-svc-fork)
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->so-vits-svc-fork) (1.1.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa->so-vits-svc-fork) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->so-vits-svc-fork) (4.3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->so-vits-svc-fork) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->so-vits-svc-fork) (2.4.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa->so-vits-svc-fork) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from SoundFile->so-vits-svc-fork) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->SoundFile->so-vits-svc-fork) (2.22)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi==0.111.1->so-vits-svc-fork) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.12.0->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.12.0->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.12.0->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi==0.111.1->so-vits-svc-fork)
#   Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0->fastapi==0.111.1->so-vits-svc-fork) (15.0.1)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx->so-vits-svc-fork) (5.29.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->so-vits-svc-fork) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->so-vits-svc-fork) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->so-vits-svc-fork) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->so-vits-svc-fork) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->so-vits-svc-fork) (3.1.3)
# Downloading so_vits_svc_fork-4.2.26-py3-none-any.whl (94 kB)
# Downloading fastapi-0.111.1-py3-none-any.whl (92 kB)
# Downloading lightning-2.5.1.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 27.8 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 166.8 MB/s eta 0:00:00
# Downloading PySimpleGUI_4_foss-4.60.4.1-py3-none-any.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.5/689.5 kB 41.3 MB/s eta 0:00:00
# Downloading setuptools-69.5.1-py3-none-any.whl (894 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 894.6/894.6 kB 46.0 MB/s eta 0:00:00
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 54.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 165.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 167.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 45.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 73.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 144.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 126.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 62.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 154.2 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 58.6 MB/s eta 0:00:00
# Downloading tqdm_joblib-0.0.4-py3-none-any.whl (1.7 kB)
# Downloading cm_time-0.1.2-py3-none-any.whl (7.8 kB)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Downloading fastapi_cli-0.0.7-py3-none-any.whl (10 kB)
# Downloading pebble-5.1.1-py3-none-any.whl (34 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading rich_toolkit-0.14.5-py3-none-any.whl (24 kB)
# Downloading torchcrepe-0.0.23-py3-none-any.whl (72.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 MB 89.3 MB/s eta 0:00:00
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 138.8 MB/s eta 0:00:00
# Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (454 kB)
# Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 172.6 MB/s eta 0:00:00
# Downloading onnxoptimizer-0.3.13-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (678 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 678.1/678.1 kB 40.0 MB/s eta 0:00:00
# Downloading onnxsim-0.4.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 92.8 MB/s eta 0:00:00
# Downloading praat_parselmouth-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 52.3 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 52.7 MB/s eta 0:00:00
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 124.4 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Building wheels for collected packages: pyworld
#   Building wheel for pyworld (pyproject.toml) ... done
#   Created wheel for pyworld: filename=pyworld-0.3.5-cp311-cp311-linux_x86_64.whl size=924300 sha256=9386a61b5439f4bc99b03f4ff7d1d0b6392e703d064b028c00f2bc41ba21ea03
#   Stored in directory: /root/.cache/pip/wheels/26/f0/db/ebcd5cdfe5ad7d229917d3a8db6f18f0cf40f099bf878e294d
# Successfully built pyworld
# Installing collected packages: pysimplegui-4-foss, uvloop, uvicorn, tqdm-joblib, setuptools, python-multipart, python-dotenv, pebble, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, httptools, dnspython, cm-time, watchfiles, tensorboardx, starlette, sounddevice, pyworld, praat-parselmouth, onnx, nvidia-cusparse-cu12, nvidia-cudnn-cu12, lightning-utilities, email_validator, rich-toolkit, resampy, onnxsim, onnxoptimizer, nvidia-cusolver-cu12, fastapi-cli, torchmetrics, fastapi, torchcrepe, pytorch-lightning, lightning, so-vits-svc-fork
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42/42 [so-vits-svc-fork]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed cm-time-0.1.2 dnspython-2.7.0 email_validator-2.2.0 fastapi-0.111.1 fastapi-cli-0.0.7 httptools-0.6.4 lightning-2.5.1.post0 lightning-utilities-0.14.3 numpy-1.26.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 onnx-1.17.0 onnxoptimizer-0.3.13 onnxsim-0.4.36 pebble-5.1.1 praat-parselmouth-0.4.5 pysimplegui-4-foss-4.60.4.1 python-dotenv-1.1.0 python-multipart-0.0.20 pytorch-lightning-2.5.1.post0 pyworld-0.3.5 resampy-0.4.3 rich-toolkit-0.14.5 setuptools-69.5.1 so-vits-svc-fork-4.2.26 sounddevice-0.5.1 starlette-0.37.2 tensorboardx-2.6.2.2 torchcrepe-0.0.23 torchmetrics-1.7.1 tqdm-joblib-0.0.4 uvicorn-0.34.2 uvloop-0.21.0 watchfiles-1.0.5

# %% [markdown]
# ## Training

# %%
#@title Make dataset directory
# !mkdir -p "dataset_raw"

# %%
#!rm -r "dataset_raw"
#!rm -r "dataset/44k"

# %%
#@title Copy your dataset
#@markdown **We assume that your dataset is in your Google Drive's `so-vits-svc-fork/dataset/(speaker_name)` directory.**
DATASET_NAME = "yen-uyen-hau-cung-nhu-y-truyen" #@param {type: "string"}
# !cp -R /content/drive/MyDrive/so-vits-svc-fork/dataset/{DATASET_NAME}/ -t "dataset_raw/"

# %%
#@title Download dataset (Tsukuyomi-chan JVS)
#@markdown You can download this dataset if you don't have your own dataset.
#@markdown Make sure you agree to the license when using this dataset.
#@markdown https://tyc.rei-yumesaki.net/material/corpus/#toc6
# !wget https://tyc.rei-yumesaki.net/files/sozai-tyc-corpus1.zip
# !unzip sozai-tyc-corpus1.zip
# !mv "/content/つくよみちゃんコーパス Vol.1 声優統計コーパス（JVSコーパス準拠）/おまけ：WAV（+12dB増幅＆高音域削減）/WAV（+12dB増幅＆高音域削減）" "dataset_raw/tsukuyomi"

# %%
#@title Automatic preprocessing
# !svc pre-resample
# Out:
# [17:23:20] INFO     [17:23:20] NumExpr defaulting to 12 threads.    ]8;id=122533;file:///usr/local/lib/python3.11/dist-packages/numexpr/utils.py\utils.py]8;;\:]8;id=937356;file:///usr/local/lib/python3.11/dist-packages/numexpr/utils.py#162\162]8;;\
# 2025-05-10 17:23:23.655854: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-10 17:23:23.672454: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746897803.693766    4313 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746897803.700337    4313 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-10 17:23:23.722208: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Preprocessing:  58% 416/715 [00:20<00:01, 204.28it/s][17:23:49] WARNING  [17:23:49]                                   ]8;id=578915;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=844523;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/so_v
#                     its_svc_fork/preprocessing/preprocess_resamp
#                     le.py:62: UserWarning: PySoundFile failed.
#                     Trying audioread instead.
#                       audio, sr = librosa.load(input_path,
#                     sr=sr, mono=True)
#
#            WARNING  [17:23:49]                                   ]8;id=55049;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=757210;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/libr
#                     osa/core/audio.py:184: FutureWarning:
#                     librosa.core.audio.__audioread_load
#                             Deprecated as of librosa version
#                     0.10.0.
#                             It will be removed in librosa
#                     version 1.0.
#                       y, sr_native = __audioread_load(path,
#                     offset, duration, dtype)
#
# Preprocessing:  65% 464/715 [00:20<00:01, 239.65it/s][17:23:50] WARNING  [17:23:50] Failed to load          ]8;id=30976;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_resample.py\preprocess_resample.py]8;;\:]8;id=502235;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_resample.py#67\67]8;;\
#                     dataset_raw/yen-uyen-hau-cung-nhu-
#                     y-truyen/.DS_Store due to
# Preprocessing: 100% 715/715 [00:20<00:00, 34.09it/s]

# %%
# !svc pre-config
# Out:
# [17:24:33] INFO     [17:24:33] NumExpr defaulting to 12 threads.    ]8;id=628602;file:///usr/local/lib/python3.11/dist-packages/numexpr/utils.py\utils.py]8;;\:]8;id=248678;file:///usr/local/lib/python3.11/dist-packages/numexpr/utils.py#162\162]8;;\
# 2025-05-10 17:24:34.883244: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-10 17:24:34.900963: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746897874.922336    4800 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746897874.928904    4800 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-10 17:24:34.950681: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#   0% 0/714 [00:00<?, ?it/s][17:24:37] WARNING  [17:24:37]                                   ]8;id=24087;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=513204;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/so_v
#                     its_svc_fork/preprocessing/preprocess_flist_
#                     config.py:41: FutureWarning: get_duration()
#                     keyword argument 'filename' has been renamed
#                     to 'path' in version 0.10.0.
#                             This alias will be removed in
#                     version 1.0.
#                       if get_duration(filename=path) < 0.3:
#
# 100% 714/714 [00:00<00:00, 1816.13it/s]
# [17:24:38] INFO     [17:24:38] Writing             ]8;id=426626;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py\preprocess_flist_config.py]8;;\:]8;id=46520;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py#54\54]8;;\
#                     filelists/44k/train.txt
#            INFO     [17:24:38] Writing             ]8;id=314676;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py\preprocess_flist_config.py]8;;\:]8;id=956936;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py#60\60]8;;\
#                     filelists/44k/val.txt
#            INFO     [17:24:38] Writing             ]8;id=346937;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py\preprocess_flist_config.py]8;;\:]8;id=209946;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py#64\64]8;;\
#                     filelists/44k/test.txt
#            INFO     [17:24:38] Writing             ]8;id=927562;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py\preprocess_flist_config.py]8;;\:]8;id=253431;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_flist_config.py#83\83]8;;\
#                     configs/44k/config.json

# %%
#@title Export configs file
#@markdown This assumes that you want to save the **config.json** on the default location. There will be also a backup file created in case the action is done accidentally.!cp configs/44k/config.json configs/44k/config.bkp.json!cp drive/MyDrive/so-vits-svc-fork/config.json configs/44k

# %%
#@title Import configs file (Optional Step, NOT REQUIRED)
#@markdown This assumes that you are saving the **config.json** on the default location. There will be also a backup file created in case the action is done accidentally.!cp drive/MyDrive/so-vits-svc-fork/config.json drive/MyDrive/so-vits-svc-fork/config.bkp.json!cp configs/44k/config.json drive/MyDrive/so-vits-svc-fork

# %%
F0_METHOD = "crepe" #@param ["crepe", "crepe-tiny", "parselmouth", "dio", "harvest"]
# !svc pre-hubert -fm {F0_METHOD}
# Out:
# [17:26:04] INFO     [17:26:04] NumExpr defaulting to 12 threads.    ]8;id=851433;file:///usr/local/lib/python3.11/dist-packages/numexpr/utils.py\utils.py]8;;\:]8;id=840658;file:///usr/local/lib/python3.11/dist-packages/numexpr/utils.py#162\162]8;;\
# 2025-05-10 17:26:05.583596: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-10 17:26:05.601095: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746897965.622303    5236 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746897965.628770    5236 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-10 17:26:05.650409: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [17:26:08] INFO     [17:26:08] n_jobs automatically  ]8;id=278092;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_hubert_f0.py\preprocess_hubert_f0.py]8;;\:]8;id=863909;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/preprocessing/preprocess_hubert_f0.py#142\142]8;;\
#                     set to 5, memory: 23034 MiB
# 2025-05-10 17:26:14.030022: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746897974.050536    5325 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746897974.056958    5325 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-10 17:26:14.111030: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-10 17:26:14.111601: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-10 17:26:14.111882: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746897974.132487    5326 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746897974.133142    5328 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746897974.134669    5324 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746897974.138978    5326 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1746897974.139484    5328 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1746897974.141104    5324 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-10 17:26:14.171832: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746897974.193585    5327 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746897974.199990    5327 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json: 100% 1.39k/1.39k [00:00<00:00, 8.87MB/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# [17:26:17] WARNING  [17:26:17] Xet Storage is enabled for  ]8;id=224806;file:///usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py\file_download.py]8;;\:]8;id=972667;file:///usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py#1670\1670]8;;\
#                     this repo, but the 'hf_xet' package is
#                     not installed. Falling back to regular
#                     HTTP download. For better performance,
#                     install the package with: `pip install
#                     huggingface_hub[hf_xet]` or `pip
#                     install hf_xet`
# pytorch_model.bin: 100% 378M/378M [00:01<00:00, 340MB/s]
#
#
#
#   0% 0/143 [00:00<?, ?it/s]
#   0% 0/143 [00:00<?, ?it/s]
#
#
#
#   0% 0/143 [00:00<?, ?it/s]
#
#   0% 0/143 [00:00<?, ?it/s]Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# [17:26:19] WARNING  [17:26:19] Xet Storage is enabled for  ]8;id=123402;file:///usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py\file_download.py]8;;\:]8;id=446814;file:///usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py#1670\1670]8;;\
#                     this repo, but the 'hf_xet' package is
#                     not installed. Falling back to regular
#                     HTTP download. For better performance,
#                     install the package with: `pip install
#                     huggingface_hub[hf_xet]` or `pip
#                     install hf_xet`
# model.safetensors: 100% 378M/378M [00:02<00:00, 139MB/s]
# [17:26:24] INFO     [17:26:24] F0 inference time:       3.418s, RTF:   ]8;id=113227;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=748802;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.925
# [17:26:24] INFO     [17:26:24] F0 inference time:       3.362s, RTF:   ]8;id=708734;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=831335;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     2.682
# [17:26:24] INFO     [17:26:24] F0 inference time:       3.418s, RTF:   ]8;id=184154;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=663005;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.710
# [17:26:24] INFO     [17:26:24] F0 inference time:       3.323s, RTF:   ]8;id=107635;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=385962;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.537
#            INFO     [17:26:24] HuBERT inference time  : 0.557s,     ]8;id=660760;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=56849;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.090
#            INFO     [17:26:24] HuBERT inference time  : 0.563s,     ]8;id=608967;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=24754;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.152
#            INFO     [17:26:24] HuBERT inference time  : 0.563s,     ]8;id=315101;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=915083;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.117
#            INFO     [17:26:24] HuBERT inference time  : 0.563s,     ]8;id=109640;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=518963;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.449
#            WARNING  [17:26:24]                                   ]8;id=899387;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=111097;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/torc
#                     h/functional.py:709: UserWarning: stft with
#                     return_complex=False is deprecated. In a
#                     future pytorch release, stft will return
#                     complex tensors for all inputs, and
#                     return_complex=False will raise an error.
#                     Note: you can still call torch.view_as_real
#                     on the complex output to recover the old
#                     return format. (Triggered internally at
#                     /pytorch/aten/src/ATen/native/SpectralOps.cp
#                     p:873.)
#                       return _VF.stft(  # type:
#                     ignore[attr-defined]
#
#            WARNING  [17:26:24]                                   ]8;id=850264;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=265780;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/torc
#                     h/functional.py:709: UserWarning: stft with
#                     return_complex=False is deprecated. In a
#                     future pytorch release, stft will return
#                     complex tensors for all inputs, and
#                     return_complex=False will raise an error.
#                     Note: you can still call torch.view_as_real
#                     on the complex output to recover the old
#                     return format. (Triggered internally at
#                     /pytorch/aten/src/ATen/native/SpectralOps.cp
#                     p:873.)
#                       return _VF.stft(  # type:
#                     ignore[attr-defined]
#
#            WARNING  [17:26:24]                                   ]8;id=266924;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=23687;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/torc
#                     h/functional.py:709: UserWarning: stft with
#                     return_complex=False is deprecated. In a
#                     future pytorch release, stft will return
#                     complex tensors for all inputs, and
#                     return_complex=False will raise an error.
#                     Note: you can still call torch.view_as_real
#                     on the complex output to recover the old
#                     return format. (Triggered internally at
#                     /pytorch/aten/src/ATen/native/SpectralOps.cp
#                     p:873.)
#                       return _VF.stft(  # type:
#                     ignore[attr-defined]
#
#            WARNING  [17:26:24]                                   ]8;id=217550;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=123526;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/torc
#                     h/functional.py:709: UserWarning: stft with
#                     return_complex=False is deprecated. In a
#                     future pytorch release, stft will return
#                     complex tensors for all inputs, and
#                     return_complex=False will raise an error.
#                     Note: you can still call torch.view_as_real
#                     on the complex output to recover the old
#                     return format. (Triggered internally at
#                     /pytorch/aten/src/ATen/native/SpectralOps.cp
#                     p:873.)
#                       return _VF.stft(  # type:
#                     ignore[attr-defined]
#
#   1% 1/143 [00:05<11:50,  5.01s/it]
#
#   1% 1/143 [00:05<11:51,  5.01s/it]
#
#
#
#   1% 1/142 [00:05<11:46,  5.01s/it]
#   1% 1/143 [00:05<11:51,  5.01s/it][17:26:25] INFO     [17:26:25] F0 inference time:       0.200s, RTF:   ]8;id=826699;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=937353;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.091
#            INFO     [17:26:25] HuBERT inference time  : 0.019s,     ]8;id=419342;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=974315;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.009
# [17:26:25] INFO     [17:26:25] F0 inference time:       0.230s, RTF:   ]8;id=290467;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=347488;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.086
#
#   1% 2/143 [00:05<05:11,  2.21s/it]           INFO     [17:26:25] HuBERT inference time  : 0.022s,     ]8;id=703012;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=366334;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.008
#
#
#   1% 2/143 [00:05<05:14,  2.23s/it]           INFO     [17:26:25] F0 inference time:       0.211s, RTF:   ]8;id=323562;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=447038;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.106
#            INFO     [17:26:25] HuBERT inference time  : 0.022s,     ]8;id=616790;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=683705;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.011
#
#
#   2% 3/143 [00:05<03:07,  1.34s/it][17:26:25] INFO     [17:26:25] F0 inference time:       0.838s, RTF:   ]8;id=984010;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=697347;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.093
#            INFO     [17:26:25] HuBERT inference time  : 0.025s,     ]8;id=519305;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=995024;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#
#
#
#   1% 2/142 [00:05<06:07,  2.62s/it][17:26:26] INFO     [17:26:26] F0 inference time:       1.452s, RTF:   ]8;id=509944;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=79656;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.109
#            INFO     [17:26:26] HuBERT inference time  : 0.021s,     ]8;id=976519;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=200413;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#   1% 2/143 [00:06<07:09,  3.04s/it][17:26:26] INFO     [17:26:26] F0 inference time:       0.779s, RTF:   ]8;id=690473;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=202568;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.130
#            INFO     [17:26:26] HuBERT inference time  : 0.024s,     ]8;id=485400;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=238224;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#            INFO     [17:26:26] F0 inference time:       0.116s, RTF:   ]8;id=49052;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=862734;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.178
#            INFO     [17:26:26] HuBERT inference time  : 0.021s,     ]8;id=534960;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=783858;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.033
#
#
#
#
#   2% 3/143 [00:06<04:01,  1.73s/it][17:26:27] INFO     [17:26:27] F0 inference time:       1.644s, RTF:   ]8;id=946111;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=538971;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.117
#            INFO     [17:26:27] HuBERT inference time  : 0.021s,     ]8;id=930087;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=446177;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#
#
# [17:26:27] INFO     [17:26:27] F0 inference time:       0.565s, RTF:   ]8;id=733835;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=629083;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.106
#   3% 4/143 [00:07<03:32,  1.53s/it]           INFO     [17:26:27] HuBERT inference time  : 0.022s,     ]8;id=307295;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=492918;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#
#
#
#
#   3% 4/142 [00:07<03:07,  1.36s/it]           INFO     [17:26:27] F0 inference time:       0.133s, RTF:   ]8;id=44038;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=772395;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.122
#            INFO     [17:26:27] HuBERT inference time  : 0.020s,     ]8;id=211410;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=534672;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.018
#
#
#   3% 5/143 [00:07<02:23,  1.04s/it]           INFO     [17:26:27] F0 inference time:       0.162s, RTF:   ]8;id=754571;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=597355;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.086
#            INFO     [17:26:27] HuBERT inference time  : 0.020s,     ]8;id=908278;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=943611;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.011
# [17:26:27] INFO     [17:26:27] F0 inference time:       6.468s, RTF:   ]8;id=960699;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=403423;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.153
#
#
#
#
#   4% 5/142 [00:07<02:09,  1.06it/s]           INFO     [17:26:27] HuBERT inference time  : 0.099s,     ]8;id=564233;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=960512;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
# [17:26:27] INFO     [17:26:27] F0 inference time:       2.535s, RTF:   ]8;id=736410;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=123756;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.107
#            INFO     [17:26:27] HuBERT inference time  : 0.020s,     ]8;id=667559;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=731800;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
# [17:26:28] WARNING  [17:26:28]                                   ]8;id=373586;file:///usr/lib/python3.11/warnings.py\warnings.py]8;;\:]8;id=603806;file:///usr/lib/python3.11/warnings.py#110\110]8;;\
#                     /usr/local/lib/python3.11/dist-packages/torc
#                     h/functional.py:709: UserWarning: stft with
#                     return_complex=False is deprecated. In a
#                     future pytorch release, stft will return
#                     complex tensors for all inputs, and
#                     return_complex=False will raise an error.
#                     Note: you can still call torch.view_as_real
#                     on the complex output to recover the old
#                     return format. (Triggered internally at
#                     /pytorch/aten/src/ATen/native/SpectralOps.cp
#                     p:873.)
#                       return _VF.stft(  # type:
#                     ignore[attr-defined]
#
#
#   2% 3/143 [00:08<05:51,  2.51s/it][17:26:28] INFO     [17:26:28] F0 inference time:       0.482s, RTF:   ]8;id=239490;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=300415;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.136
#            INFO     [17:26:28] HuBERT inference time  : 0.024s,     ]8;id=521365;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=21090;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.007
#
#
#
#
#   4% 6/142 [00:08<01:49,  1.24it/s]
#
#
#   1% 1/143 [00:08<19:29,  8.24s/it][17:26:28] INFO     [17:26:28] F0 inference time:       0.374s, RTF:   ]8;id=532261;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=357583;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.084
#            INFO     [17:26:28] HuBERT inference time  : 0.020s,     ]8;id=354267;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=758422;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#
#   3% 4/143 [00:08<03:55,  1.70s/it][17:26:28] INFO     [17:26:28] F0 inference time:       1.305s, RTF:   ]8;id=417504;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=792211;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.089
#            INFO     [17:26:28] HuBERT inference time  : 0.019s,     ]8;id=706752;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=892657;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#   4% 6/143 [00:08<02:39,  1.17s/it][17:26:29] INFO     [17:26:29] F0 inference time:       0.930s, RTF:   ]8;id=652913;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=173412;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.096
#            INFO     [17:26:29] HuBERT inference time  : 0.053s,     ]8;id=497831;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=412905;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.005
# [17:26:29] INFO     [17:26:29] F0 inference time:       0.281s, RTF:   ]8;id=218964;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=665114;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.099
#            INFO     [17:26:29] HuBERT inference time  : 0.020s,     ]8;id=300315;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=490362;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.007
#
#
#
#   1% 2/143 [00:09<09:26,  4.02s/it]
#
#   5% 7/143 [00:09<02:01,  1.12it/s][17:26:29] INFO     [17:26:29] F0 inference time:       2.507s, RTF:   ]8;id=379447;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=513286;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.095
#            INFO     [17:26:29] HuBERT inference time  : 0.020s,     ]8;id=411812;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=14950;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#            INFO     [17:26:29] F0 inference time:       0.156s, RTF:   ]8;id=391518;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=370589;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.131
#            INFO     [17:26:29] HuBERT inference time  : 0.019s,     ]8;id=758901;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=567112;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.016
#
#
#   6% 8/143 [00:09<01:31,  1.48it/s][17:26:29] INFO     [17:26:29] F0 inference time:       0.949s, RTF:   ]8;id=635878;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=729099;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.081
#   3% 4/143 [00:09<04:53,  2.11s/it]           INFO     [17:26:29] HuBERT inference time  : 0.019s,     ]8;id=729789;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=267391;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#
#   3% 5/143 [00:09<03:21,  1.46s/it][17:26:30] INFO     [17:26:30] F0 inference time:       0.537s, RTF:   ]8;id=199213;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=75793;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.106
#            INFO     [17:26:30] HuBERT inference time  : 0.021s,     ]8;id=182439;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=329444;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
# [17:26:30] INFO     [17:26:30] F0 inference time:       0.827s, RTF:   ]8;id=551776;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=69685;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.089
# [17:26:30] INFO     [17:26:30] F0 inference time:       0.626s, RTF:   ]8;id=355735;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=602275;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.105
#   3% 5/143 [00:10<03:37,  1.57s/it]           INFO     [17:26:30] HuBERT inference time  : 0.023s,     ]8;id=63984;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=632652;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#            INFO     [17:26:30] HuBERT inference time  : 0.025s,     ]8;id=875684;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=995849;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#
#
#
#   2% 3/143 [00:10<06:04,  2.60s/it]
#
#   6% 9/143 [00:10<01:31,  1.46it/s]           INFO     [17:26:30] F0 inference time:       0.130s, RTF:   ]8;id=772374;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=360170;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.143
#            INFO     [17:26:30] HuBERT inference time  : 0.023s,     ]8;id=276554;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=973161;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.025
#
#
#
#   3% 4/143 [00:10<03:48,  1.65s/it]           INFO     [17:26:30] F0 inference time:       0.331s, RTF:   ]8;id=715238;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=280639;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.108
#            INFO     [17:26:30] HuBERT inference time  : 0.022s,     ]8;id=230743;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=476037;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.007
#   4% 6/143 [00:10<02:41,  1.18s/it]           INFO     [17:26:30] F0 inference time:       0.811s, RTF:   ]8;id=737780;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=791234;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.115
#            INFO     [17:26:30] HuBERT inference time  : 0.014s,     ]8;id=690745;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=621177;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#
#
#   7% 10/143 [00:11<01:39,  1.33it/s][17:26:31] INFO     [17:26:31] F0 inference time:       0.728s, RTF:   ]8;id=828298;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=226978;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.111
#            INFO     [17:26:31] HuBERT inference time  : 0.021s,     ]8;id=316750;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=403480;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#
#
#   3% 5/143 [00:11<03:06,  1.35s/it][17:26:31] INFO     [17:26:31] F0 inference time:       0.281s, RTF:   ]8;id=932039;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=445216;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.104
#            INFO     [17:26:31] HuBERT inference time  : 0.020s,     ]8;id=725217;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=238798;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.007
#
#
#   8% 11/143 [00:11<01:22,  1.60it/s][17:26:31] INFO     [17:26:31] F0 inference time:       1.909s, RTF:   ]8;id=136933;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=176799;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.099
#            INFO     [17:26:31] HuBERT inference time  : 0.019s,     ]8;id=893811;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=957949;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
# [17:26:31] INFO     [17:26:31] F0 inference time:       1.005s, RTF:   ]8;id=607373;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=898916;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.103
#            INFO     [17:26:31] HuBERT inference time  : 0.020s,     ]8;id=157526;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=307323;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#   5% 7/143 [00:11<02:38,  1.16s/it]
#   4% 6/143 [00:11<03:51,  1.69s/it]           INFO     [17:26:31] F0 inference time:       0.632s, RTF:   ]8;id=351446;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=326182;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.097
#            INFO     [17:26:31] HuBERT inference time  : 0.021s,     ]8;id=188271;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=234544;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#
#
#   4% 6/143 [00:11<02:35,  1.13s/it][17:26:32] INFO     [17:26:32] F0 inference time:       4.486s, RTF:   ]8;id=628676;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=732982;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.080
# [17:26:32] INFO     [17:26:32] F0 inference time:       1.061s, RTF:   ]8;id=881670;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=425779;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.081
#            INFO     [17:26:32] HuBERT inference time  : 0.019s,     ]8;id=720457;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=373730;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.000
#            INFO     [17:26:32] HuBERT inference time  : 0.020s,     ]8;id=592244;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=953318;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#   6% 8/143 [00:12<02:38,  1.17s/it]           INFO     [17:26:32] F0 inference time:       0.158s, RTF:   ]8;id=93467;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=805248;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.079
#            INFO     [17:26:32] HuBERT inference time  : 0.021s,     ]8;id=445607;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=195946;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.010
#   6% 9/143 [00:13<01:56,  1.15it/s]
#
#
#
#   5% 7/142 [00:13<04:50,  2.15s/it][17:26:33] INFO     [17:26:33] F0 inference time:       1.473s, RTF:   ]8;id=985042;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=400144;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.084
#            INFO     [17:26:33] HuBERT inference time  : 0.020s,     ]8;id=739132;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=419581;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#
#   5% 7/143 [00:13<02:55,  1.29s/it][17:26:33] INFO     [17:26:33] F0 inference time:       0.686s, RTF:   ]8;id=174966;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=627506;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.076
#            INFO     [17:26:33] HuBERT inference time  : 0.010s,     ]8;id=881;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=770010;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#
#
#   6% 8/142 [00:13<03:50,  1.72s/it][17:26:34] INFO     [17:26:34] F0 inference time:       0.554s, RTF:   ]8;id=136188;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=584665;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.133
#            INFO     [17:26:34] HuBERT inference time  : 0.019s,     ]8;id=24316;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=127483;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.005
# [17:26:34] INFO     [17:26:34] F0 inference time:       0.989s, RTF:   ]8;id=680675;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=591629;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.109
#
#
#
#
#   6% 9/142 [00:14<03:03,  1.38s/it]           INFO     [17:26:34] HuBERT inference time  : 0.020s,     ]8;id=193970;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=723368;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#
#
#
#   6% 8/143 [00:14<02:47,  1.24s/it][17:26:35] INFO     [17:26:35] F0 inference time:       3.937s, RTF:   ]8;id=60535;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=541746;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.094
#            INFO     [17:26:35] HuBERT inference time  : 0.019s,     ]8;id=869401;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=655677;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.000
# [17:26:35] INFO     [17:26:35] F0 inference time:       1.187s, RTF:   ]8;id=504164;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=769373;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.117
#            INFO     [17:26:35] HuBERT inference time  : 0.020s,     ]8;id=753935;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=449313;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#
#
#
#   6% 9/143 [00:16<02:49,  1.27s/it]
#   5% 7/143 [00:16<05:50,  2.58s/it][17:26:36] INFO     [17:26:36] F0 inference time:       3.296s, RTF:   ]8;id=128188;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=433071;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.106
# [17:26:36] INFO     [17:26:36] F0 inference time:       1.830s, RTF:   ]8;id=956587;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=121181;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.107
#            INFO     [17:26:36] HuBERT inference time  : 0.021s,     ]8;id=286964;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=813829;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
# ...
#                     0.084
#            INFO     [17:28:51] F0 inference time:       0.209s, RTF:   ]8;id=850623;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=179791;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.073
#            INFO     [17:28:51] HuBERT inference time  : 0.020s,     ]8;id=180250;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=307720;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#            INFO     [17:28:51] HuBERT inference time  : 0.020s,     ]8;id=410438;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=65137;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.007
#
#
#
#
#  94% 134/142 [02:31<00:06,  1.30it/s]
#
#
#  95% 136/143 [02:31<00:02,  2.62it/s][17:28:52] INFO     [17:28:52] F0 inference time:       0.652s, RTF:   ]8;id=495660;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=934425;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.071
#            INFO     [17:28:52] HuBERT inference time  : 0.019s,     ]8;id=583061;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=216483;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#
#
#
#  96% 137/143 [02:32<00:02,  2.07it/s]           INFO     [17:28:52] F0 inference time:       0.081s, RTF:   ]8;id=464534;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=117770;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.089
#            INFO     [17:28:52] HuBERT inference time  : 0.010s,     ]8;id=109006;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=704207;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.011
#
#
#
#  97% 138/143 [02:32<00:01,  2.68it/s][17:28:52] INFO     [17:28:52] F0 inference time:       1.082s, RTF:   ]8;id=395393;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=587643;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.076
#            INFO     [17:28:52] HuBERT inference time  : 0.019s,     ]8;id=262570;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=860567;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#
#
#  95% 135/142 [02:32<00:06,  1.11it/s]           INFO     [17:28:52] F0 inference time:       0.614s, RTF:   ]8;id=628665;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=497137;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.079
#            INFO     [17:28:52] HuBERT inference time  : 0.019s,     ]8;id=949754;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=291055;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#
#
#
#  97% 139/143 [02:32<00:01,  2.12it/s]           INFO     [17:28:52] F0 inference time:       0.413s, RTF:   ]8;id=506953;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=282377;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.096
#            INFO     [17:28:52] HuBERT inference time  : 0.011s,     ]8;id=58051;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=908752;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#
#
#
#
#  96% 136/142 [02:33<00:04,  1.30it/s][17:28:53] INFO     [17:28:53] F0 inference time:       0.249s, RTF:   ]8;id=835037;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=413083;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.083
# [17:28:53] INFO     [17:28:53] F0 inference time:       0.387s, RTF:   ]8;id=809288;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=615620;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.077
#            INFO     [17:28:53] HuBERT inference time  : 0.017s,     ]8;id=241594;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=725517;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.006
#            INFO     [17:28:53] HuBERT inference time  : 0.020s,     ]8;id=286698;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=869388;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#
#
#
#
#  96% 137/142 [02:33<00:03,  1.60it/s]
#
#
#  98% 140/143 [02:33<00:01,  2.15it/s]           INFO     [17:28:53] F0 inference time:       0.598s, RTF:   ]8;id=918564;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=646402;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.081
#            INFO     [17:28:53] HuBERT inference time  : 0.020s,     ]8;id=838994;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=863101;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#
#
#
#  97% 138/142 [02:34<00:02,  1.55it/s][17:28:54] INFO     [17:28:54] F0 inference time:       1.424s, RTF:   ]8;id=688519;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=285596;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.092
#            INFO     [17:28:54] HuBERT inference time  : 0.019s,     ]8;id=726180;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=571273;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#
#  99% 141/143 [02:34<00:01,  1.26it/s][17:28:55] INFO     [17:28:55] F0 inference time:       1.111s, RTF:   ]8;id=775282;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=676050;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.085
#            INFO     [17:28:55] HuBERT inference time  : 0.019s,     ]8;id=647182;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=637523;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#
#
#  98% 139/142 [02:35<00:02,  1.23it/s][17:28:55] INFO     [17:28:55] F0 inference time:       4.894s, RTF:   ]8;id=648276;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=110525;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.083
#            INFO     [17:28:55] HuBERT inference time  : 0.017s,     ]8;id=636887;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=77823;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.000
# [17:28:56] INFO     [17:28:56] F0 inference time:       0.885s, RTF:   ]8;id=789756;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=841285;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.084
#            INFO     [17:28:56] HuBERT inference time  : 0.010s,     ]8;id=72495;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=676338;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#
#
#  99% 140/142 [02:36<00:01,  1.17it/s]
#
#  97% 139/143 [02:36<00:08,  2.11s/it][17:28:56] INFO     [17:28:56] F0 inference time:       1.257s, RTF:   ]8;id=141632;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=362823;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.075
#            INFO     [17:28:56] HuBERT inference time  : 0.020s,     ]8;id=856493;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=536345;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#
#  99% 142/143 [02:36<00:00,  1.03it/s][17:28:56] INFO     [17:28:56] F0 inference time:       0.229s, RTF:   ]8;id=105502;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=92557;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.077
#            INFO     [17:28:56] HuBERT inference time  : 0.016s,     ]8;id=5442;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=285713;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.005
#
#
#  98% 140/143 [02:36<00:04,  1.56s/it][17:28:57] INFO     [17:28:57] F0 inference time:       0.604s, RTF:   ]8;id=988783;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=389371;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.093
#            INFO     [17:28:57] HuBERT inference time  : 0.019s,     ]8;id=30951;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=887944;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.003
#
#
#  99% 141/143 [02:37<00:02,  1.29s/it][17:28:57] INFO     [17:28:57] F0 inference time:       1.006s, RTF:   ]8;id=886849;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=184166;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.083
#            INFO     [17:28:57] HuBERT inference time  : 0.019s,     ]8;id=342038;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=412196;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.002
#
#
#
# 100% 143/143 [02:37<00:00,  1.10s/it]
# [17:28:58] INFO     [17:28:58] F0 inference time:       2.520s, RTF:   ]8;id=655710;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=284318;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.078
#            INFO     [17:28:58] HuBERT inference time  : 0.020s,     ]8;id=985088;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=789488;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#
#
#  99% 141/142 [02:38<00:01,  1.41s/it][17:28:59] INFO     [17:28:59] F0 inference time:       2.012s, RTF:   ]8;id=157966;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=268890;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.076
#            INFO     [17:28:59] HuBERT inference time  : 0.021s,     ]8;id=140610;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=497382;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.001
#
#
#  99% 142/143 [02:39<00:01,  1.57s/it][17:28:59] INFO     [17:28:59] F0 inference time:       0.517s, RTF:   ]8;id=632736;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=380542;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.081
#            INFO     [17:28:59] HuBERT inference time  : 0.023s,     ]8;id=740473;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=901259;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.004
#
#
#
#
# 100% 142/142 [02:39<00:00,  1.12s/it]
#            INFO     [17:28:59] F0 inference time:       0.295s, RTF:   ]8;id=220592;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py\f0.py]8;;\:]8;id=819932;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/f0.py#214\214]8;;\
#                     0.078
#            INFO     [17:28:59] HuBERT inference time  : 0.020s,     ]8;id=34073;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py\utils.py]8;;\:]8;id=766691;file:///usr/local/lib/python3.11/dist-packages/so_vits_svc_fork/utils.py#234\234]8;;\
#                     RTF: 0.005
#
#
# 100% 143/143 [02:39<00:00,  1.12s/it]

# %%
#@title Train
# %load_ext tensorboard
# %tensorboard --logdir drive/MyDrive/so-vits-svc-fork/logs/44k
# !svc train --model-path drive/MyDrive/so-vits-svc-fork/logs/44k

# %% [markdown]
# ## Training Cluster model

# %%
# !svc train-cluster --output-path drive/MyDrive/so-vits-svc-fork/logs/44k/kmeans.pt

# %% [markdown]
# ## Inference

# %%
#@title Get the author's voice as a source
import random
NAME = str(random.randint(1, 49))
TYPE = "fsd50k" #@param ["", "digit", "dog", "fsd50k"]
CUSTOM_FILEPATH = "" #@param {type: "string"}
if CUSTOM_FILEPATH != "":
    NAME = CUSTOM_FILEPATH
else:
    # it is extremely difficult to find a voice that can download from the internet directly
    if TYPE == "dog":
        # !wget -N f"https://huggingface.co/datasets/437aewuh/dog-dataset/resolve/main/dogs/dogs_{NAME:.0000}.wav" -O {NAME}.wav
    elif TYPE == "digit":
        # george, jackson, lucas, nicolas, ...
        # !wget -N f"https://github.com/Jakobovski/free-spoken-digit-dataset/raw/master/recordings/0_george_{NAME}.wav" -O {NAME}.wav
    elif TYPE == "fsd50k":
        # !wget -N f"https://huggingface.co/datasets/Fhrozen/FSD50k/blob/main/clips/dev/{10000+int(NAME)}.wav" -O {NAME}.wav
    else:
        # !wget -N f"https://zunko.jp/sozai/utau/voice_{"kiritan" if NAME < 25 else "itako"}{NAME % 5 + 1}.wav" -O {NAME}.wav
from IPython.display import Audio, display
display(Audio(f"{NAME}.wav"))

# %%
#@title Use trained model
#@markdown **Put your .wav file in `so-vits-svc-fork/audio` directory**
from IPython.display import Audio, display
# !svc infer drive/MyDrive/so-vits-svc-fork/audio/{NAME}.wav -m drive/MyDrive/so-vits-svc-fork/logs/44k/ -c drive/MyDrive/so-vits-svc-fork/logs/44k/config.json
display(Audio(f"drive/MyDrive/so-vits-svc-fork/audio/{NAME}.out.wav", autoplay=True))

# %%
##@title Use trained model (with cluster)
# !svc infer {NAME}.wav -s speaker -r 0.1 -m drive/MyDrive/so-vits-svc-fork/logs/44k/ -c drive/MyDrive/so-vits-svc-fork/logs/44k/config.json -k drive/MyDrive/so-vits-svc-fork/logs/44k/kmeans.pt
display(Audio(f"{NAME}.out.wav", autoplay=True))

# %% [markdown]
# ### Pretrained models

# %%
#@title https://huggingface.co/TachibanaKimika/so-vits-svc-4.0-models/tree/main
# !wget -N "https://huggingface.co/TachibanaKimika/so-vits-svc-4.0-models/resolve/main/riri/G_riri_220.pth"
# !wget -N "https://huggingface.co/TachibanaKimika/so-vits-svc-4.0-models/resolve/main/riri/config.json"

# %%
# !svc infer {NAME}.wav -c config.json -m G_riri_220.pth
display(Audio(f"{NAME}.out.wav", autoplay=True))

# %%
#@title https://huggingface.co/therealvul/so-vits-svc-4.0/tree/main
# !wget -N "https://huggingface.co/therealvul/so-vits-svc-4.0/resolve/main/Pinkie%20(speaking%20sep)/G_166400.pth"
# !wget -N "https://huggingface.co/therealvul/so-vits-svc-4.0/resolve/main/Pinkie%20(speaking%20sep)/config.json"

# %%
# !svc infer {NAME}.wav --speaker "Pinkie {neutral}" -c config.json -m G_166400.pth
display(Audio(f"{NAME}.out.wav", autoplay=True))
